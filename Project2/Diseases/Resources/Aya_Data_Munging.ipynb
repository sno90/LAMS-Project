# %%
# import dependencies
import os
import csv
import pandas as pd

# %%
csvpath = os.path.join('Resources', 'Communicable_Disease_VA.csv')

# %%
data_file = "year_and_condition.csv"

# %%
data_file_pd = pd.read_csv(data_file)
data_file_pd.head(2)
# Out:
#    Year               Condition
# 0  2009  Anaplasma/Ehrlichiosis
# 1  2009      Campylobacteriosis

# %%
years = data_file_pd.Year.unique()

dfs = []
for year in years:
    df = data_file_pd[data_file_pd['Year'] == year].groupby('Condition').count().reset_index()
    df.columns = ['Condition', 'Count']
    df['Year'] = year
    dfs.append(df)
    
final_df = pd.concat(dfs)
final_df.head()
# Out:
#                 Condition  Count  Year
# 0               Amebiasis     11  2009
# 1  Anaplasma/Ehrlichiosis     31  2009
# 2                Botulism      4  2009
# 3             Brucellosis      2  2009
# 4      Campylobacteriosis    103  2009

# %%
dfs = []
for year in years:
    _df = final_df[final_df['Year'] == year].sort_values('Count', ascending = False).head(10)
    dfs.append(_df)
    
final_final_df = pd.concat(dfs)
final_final_df.to_csv("Top10_Conditions_by_Year.csv")

# %% [markdown]
# ### create sqlite file

# %%
# import dependencies
import pandas as pd
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine

# %%
engine = create_engine("sqlite:///Resources/Top10Conditions.sqlite")

# %%
df = pd.read_csv("Top10_Conditions_by_Year.csv")
# C:\Users\Trisarah\LAMS-Project\Project2\Diseases\Resources\Top10_Conditions_by_Year.csv

# %%
df
# Out:
#     Year                                          Condition  Count
# 0   2009                               Hepatitis C, chronic    133
# 1   2009                                      Salmonellosis    119
# 2   2009                                 Campylobacteriosis    103
# 3   2009                               Hepatitis B, chronic    102
# 4   2009                             Varicella (Chickenpox)     85
# 5   2009                              Lead, elevated levels     82
# 6   2009                                         Giardiasis     80
# 7   2009                                       Lyme disease     65
# 8   2009                                          Pertussis     60
# 9   2009                   Streptococcus, Group A, invasive     53
# 10  2010                               Hepatitis C, chronic    132
# 11  2010                                      Salmonellosis    120
# 12  2010                               Hepatitis B, chronic    111
# ...

# %%
df.to_sql("top10",con = engine, if_exists = "append", index = False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\Anaconda3\envs\dsi\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#
# ~\Anaconda3\envs\dsi\lib\site-packages\sqlalchemy\pool.py in connect(self)
#     402         if not self._use_threadlocal:
# --> 403             return _ConnectionFairy._checkout(self)
#     404
#
# ~\Anaconda3\envs\dsi\lib\site-packages\sqlalchemy\pool.py in _checkout(cls, pool, threadconns, fairy)
#     787         if not fairy:
# --> 788             fairy = _ConnectionRecord.checkout(pool)
#     789
#
# ~\Anaconda3\envs\dsi\lib\site-packages\sqlalchemy\pool.py in checkout(cls, pool)
#     531     def checkout(cls, pool):
# --> 532         rec = pool._do_get()
#     533         try:
#
# ...

# %%
Base = automap_base()

# %%
# Use the Base class to reflect the database tables
Base.prepare(engine, reflect=True)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\Anaconda3\envs\dsi\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#
# ~\Anaconda3\envs\dsi\lib\site-packages\sqlalchemy\pool.py in unique_connection(self)
#     344         """
# --> 345         return _ConnectionFairy._checkout(self)
#     346
#
# ~\Anaconda3\envs\dsi\lib\site-packages\sqlalchemy\pool.py in _checkout(cls, pool, threadconns, fairy)
#     787         if not fairy:
# --> 788             fairy = _ConnectionRecord.checkout(pool)
#     789
#
# ~\Anaconda3\envs\dsi\lib\site-packages\sqlalchemy\pool.py in checkout(cls, pool)
#     531     def checkout(cls, pool):
# --> 532         rec = pool._do_get()
#     533         try:
#
# ...

# %%
conn = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\Anaconda3\envs\dsi\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#
# ~\Anaconda3\envs\dsi\lib\site-packages\sqlalchemy\pool.py in unique_connection(self)
#     344         """
# --> 345         return _ConnectionFairy._checkout(self)
#     346
#
# ~\Anaconda3\envs\dsi\lib\site-packages\sqlalchemy\pool.py in _checkout(cls, pool, threadconns, fairy)
#     787         if not fairy:
# --> 788             fairy = _ConnectionRecord.checkout(pool)
#     789
#
# ~\Anaconda3\envs\dsi\lib\site-packages\sqlalchemy\pool.py in checkout(cls, pool)
#     531     def checkout(cls, pool):
# --> 532         rec = pool._do_get()
#     533         try:
#
# ...

# %%
conn.execute("DROP TABLE top10")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-4fe01461b628> in <module>()
# ----> 1 conn.execute("DROP TABLE top10")
#
# NameError: name 'conn' is not defined

# %%
conn.execute("""CREATE TABLE DISEASES(
            Year Integer not null, 
            Condition Varchar not null,
            Cases Integer,
            id serial Primary Key)""")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-c388100d1422> in <module>()
# ----> 1 conn.execute("""CREATE TABLE DISEASES(
#       2             Year Integer not null,
#       3             State Varchar,
#       4             Region Varchar,
#       5             District Varchar,
#
# NameError: name 'conn' is not defined

# %%
# We can view all of the classes that automap found
Base.classes.keys()
# Out:
# []

# %%
# Create our session (link) from Python to the DB
session = Session(engine)
